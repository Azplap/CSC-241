# %% [markdown]
# # Extra Credit
# ## Austin Peng
# ## CSC 241
# ---

# %% [markdown]
# # 1) Random Network
# ---
#
# # Single Neuron Demonstration

# %%
# IMPORTS
# %matplotlib inline
import numpy as np
import math, sys, random
from pylab import *
from tqdm import tqdm_notebook as tqdm
import time
style.use('seaborn-whitegrid')
rcParams['figure.figsize'] = [20, 8]

# %%
vrest=-65
vthresh=-50
vreset=-70
tau=20

def LIF(V, I, MFR, spike):
    V += -(1/tau) * (V - vrest) + I
    if V>vthresh:
        spike=True
        V=vreset
        MFR+=1
        
    return V, MFR, spike

# %%
time = range(0,1000)
n1,n2,n3=[],[],[]

def generate_neuron(membrane_potential, I, save):
    MFR = 0
    isi_list=[]
    neuron=[]
    spike=False
    
    for t in time:
        membrane_potential, MFR, spike =LIF(membrane_potential, I, MFR, spike)
        
        if(spike==True):
            isi_list.append(t)
            spike=False    
        save.append(membrane_potential)
    
    ISI = np.diff(isi_list)
    
    return MFR, ISI

print(generate_neuron(vrest, 0.8, n1))
generate_neuron(-70, 0, n2)
generate_neuron(-60, 0, n3)
# Out:
# (16, array([60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60]))
# (0, array([], dtype=float64))

# %%
title("LIF Neuron")
xlabel("Time (ms)")
ylabel("Membrane Potential (mV)")
ylim([-75,-45])
plot(time, n1, label="I=80")
plot(time, n2, label="I=0")
plot(time, n3, label="I=0")
legend(loc='upper right')

show()

# %% [markdown]
# ---
# # Neuron Network
#
# - Dales == a neuron performs the same chemical action at all of its synaptic connections to other cells, regardless of the identity of the target cell.
# - CV == stdDev / mean
#
# ---
#
# 1. simulate n neurons (only made 1 neuron in assignment 1)
# 2. Every neuron is connected to all other ones
# 3. draw weight from uniform_dist(-w, w) for every indiviual weight.
# 4. Dales - every weight from the same neuron needs to be the same sign (pos and neg)
# 5. For ^, can use -w + 2 w rand()
# 6. CV is still from ISI

# %%
# WEIGHTS
import random
def dales(n):
    dales=[]
    for x in range(n):
        dales.append(random.randint(0, 1))
    return dales
    

def generate_weights(dales, w, n):
    weights = [[i for i in range(n)] for j in range(n)]
    
    for x in range(n):
        for y in range(n):
            if(dales[x]==0):
                weights[x][y] = -abs(random.uniform(-w, w))
            else:
                weights[x][y] = abs(random.uniform(-w, w))
                
    return weights
    
weights = generate_weights(dales(n=10), w=1, n=10)
weights = np.asarray(weights)
np.fill_diagonal(weights, 0)

# %%
vrest=-65
vthresh=-50
vreset=-70
tau=20

def LIF(V, I, spike, weights):
    V += -(1/tau) * (V - vrest) + I + weights
    if V>vthresh:
        spike=True
        V=vreset
        
    return V, spike

# %% [markdown]
# 1. Check which neurons spiked previously
# 2. For each new V(t), find relevant weights given previous neurons
# 3. If neuron 1 fired and neuron 2 is to be calc, use weight 1-2, not 2-1
# 4. Add summation to new V(t)

# %%
# generates membrane potential for each time bin
def generate_neuron_population(weights, I, n, runtime):
    # Columns: each neuron. Rows: V(t) and spikes
    track_membraneP=np.zeros((n, runtime))
    track_spikes=np.zeros((n, runtime))
    
    spike=False
    
    # time range 0-1000 
    for x in range(len(track_membraneP[0])):
        # neuron n
        for y in range(len(track_membraneP)):
            # new weight for each neuron
            sum_weight=0
            # new V(0) for each neuron
            V_start = random.uniform(vreset, vthresh)
            
            # basecase
            if (x==0):
                membrane_potential, spike = LIF(V_start, I, spike, 0)
                
                track_membraneP[y][x] = membrane_potential
                if(spike==True):
                    track_spikes[y][x] = 1
                    spike=False
                
            else:
                # find sum of weights
                current_neuron=y
                prev_spikes=track_spikes[:, [x-1]]
                
                for spike_num in range(len(prev_spikes)):
                    if(prev_spikes[spike_num]==1):
                        sum_weight += weights[:, [current_neuron]][spike_num]
                        
                
                # use prev time bin V(t) to set new one
                membrane_potential, spike= LIF(track_membraneP[y][x-1], I, spike, sum_weight)

                track_membraneP[y][x] = membrane_potential
                if(spike==True):
                    track_spikes[y][x] = 1
                    spike=False
                    
    return track_membraneP, track_spikes
                

    
    
track_membraneP, track_spikes = generate_neuron_population(weights, 0.8, 10, 1000)

# %%
def MSR_CV(track_spikes, track_membraneP):
    # find mean spike rate
    all_MSR=[]
    for x in track_spikes:
        all_MSR.append(np.sum(x))

    # find ISI CV
    all_CV=[]
    for n in range(10):
        # don't include CV of <10 spikes
        if(sum(track_spikes[n])<10):
            pass
        else:
            temp=[]
            for time in range(len(track_spikes[0])):
                if(track_spikes[n][time]==1):
                    temp.append(time)
            ISI = np.diff(temp)
            CV = np.std(ISI)/np.average(ISI)
            all_CV.append(CV)
    
    return np.average(all_MSR), np.average(all_CV)


exampleMSR, exampleCV = MSR_CV(track_spikes, track_membraneP)
print("Mean MSR: ", exampleMSR)
print("Mean CV: ", exampleCV)
# Out:
# Mean MSR:  17.0
# Mean CV:  0.02437667554868544

# %% [markdown]
# # As a function of W and I
#
# - Vary W and I and create a network for each variation
# - Plot two graphs, one of Firing Rate, one of CV. Both varied by I and W.
# ___

# %%
# neuron pop, weight w, input, runtime
def vary_W_I(n, w, I, runtime):
    # make weight matrix
    weights = generate_weights(dales(n), w, n)
    weights = np.asarray(weights)
    np.fill_diagonal(weights, 0)

    # make neuron population
    track_membraneP, track_spikes = generate_neuron_population(weights, I, n, runtime)

    # get MSR CV
    exampleMSR, exampleCV = MSR_CV(track_spikes, track_membraneP)
    time = runtime/1000
    
    return exampleMSR/time, exampleCV/time

# %%
MSR, CV = vary_W_I(10, 1, 0.8, 1000)
print(MSR, CV)
# Out:
# 16.7 0.08340650922364233

# %% [markdown]
# # With 10 neurons, 1000ms:
# ___

# %%
weight_range=10
I_range=10

plot1=np.zeros((weight_range, I_range))
plot2=np.zeros((weight_range, I_range))


for w in tqdm(range(weight_range)):
    for i in range(I_range):
        MSR, CV = vary_W_I(10, w, i, 1000)
        plot1[w,i] = MSR
        plot2[w,i] = CV
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# /home/harold/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:356: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/harold/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.imshow(plot1);
plt.title("MSR")
plt.xlabel("I(t)")
plt.ylabel("Weight")
plt.colorbar()
plt.show()

# %%
plt.imshow(plot2);
plt.title("CV")
plt.xlabel("I(t)")
plt.ylabel("Weight")
plt.colorbar()
plt.show()

# %% [markdown]
# # Discussion
# ---
#
# ### First Two Plots
#
# The MSR plot for 10 neurons over 1s makes sense. As input increases, average spike rate would naturally increase as well which can be observed by the gradient across the x-axis. I wasn't enitrely sure how the weights would affect the MSR, but it seems that as weight increases (along with input I), the MSR slightly lowers.
#
# For the CV plot with the same paramenters, the graph show that a higher weight results in a higher CV. This makes sense since greater weight would make the spikes more reliant on the summation weight part of the membrane potential equation which would make the spike times less uniform despite constant input I. This would result in higher variation relative to the mean. Input volatge does not seem to affect the CV as much as weight although there is noticable downward trend in CV as I(t) increases.

# %% [markdown]
# # With 30 neurons, 5000ms:
# ___

# %%
weight_range=10
I_range=10

plot1=np.zeros((weight_range, I_range))
plot2=np.zeros((weight_range, I_range))


for w in tqdm(range(weight_range)):
    for i in range(I_range):
        MSR, CV = vary_W_I(30, w, i, 5000)
        plot1[w,i] = MSR
        plot2[w,i] = CV
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.imshow(plot1);
plt.title("MSR")
plt.xlabel("I(t)")
plt.ylabel("Weight")
plt.colorbar()
plt.show()

# %%
plt.imshow(plot2);
plt.title("CV")
plt.xlabel("I(t)")
plt.ylabel("Weight")
plt.colorbar()
plt.show()

# %% [markdown]
# # Discussion
# ---
#
# With a larger neuron poplualtion and 5s of runtime, the graphs look a little different. The MSR still increases as I(t) increases although not as uniformly as before. There is also a strong spike in MSR around 4.5mV. For the most part it still follows what I expected it to look like.
#
# For the CV graph, my hypothesis from the first two graphs still applies and the general shape of the graph is also similar to the first two graphs. The CV values are overall lower, but more evenly distributed. Like before, an increase in I(t) lowers the CV while an increase in weight raises the CV. My reasoning behind this is the same as before.
#
#
# ## For both 30 neuron  5000ms graphs, there is an upside down L shape inconsistency at the middle bottom of the graph. I believe it is likely either a human error in the code, or a strong and uniform ISI spike response due to previous weights across all neurons.
